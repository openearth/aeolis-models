# %%
# %pylab inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from datetime import datetime
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
tide = pd.read_csv('.\\tides\CO-OPS__9440910__wl.csv',sep=',',header=1,names=['time','dz','sigma','t','dum','dum','dum','dum'])

tide.time=[datetime.strptime(tide.time[i],'%Y-%m-%d %H:%M') for i in range(len(tide.time))]

print tide
# Out:
#                     time     dz  sigma  t dum dum dum dum
# 0    2016-07-01 00:06:00  0.327  0.005  0   v   v   v   v
# 1    2016-07-01 00:12:00  0.356  0.004  0   v   v   v   v
# 2    2016-07-01 00:18:00  0.383  0.005  0   v   v   v   v
# 3    2016-07-01 00:24:00  0.420  0.006  0   v   v   v   v
# 4    2016-07-01 00:30:00  0.465  0.008  0   v   v   v   v
# 5    2016-07-01 00:36:00  0.516  0.007  0   v   v   v   v
# 6    2016-07-01 00:42:00  0.559  0.006  0   v   v   v   v
# 7    2016-07-01 00:48:00  0.601  0.006  0   v   v   v   v
# 8    2016-07-01 00:54:00  0.643  0.007  0   v   v   v   v
# 9    2016-07-01 01:00:00  0.688  0.006  0   v   v   v   v
# 10   2016-07-01 01:06:00  0.729  0.006  0   v   v   v   v
# 11   2016-07-01 01:12:00  0.773  0.006  0   v   v   v   v
# 12   2016-07-01 01:18:00  0.812  0.007  0   v   v   v   v
# 13   2016-07-01 01:24:00  0.862  0.008  0   v   v   v   v
# 14   2016-07-01 01:30:00  0.911  0.007  0   v   v   v   v
# ...

# %%
plt.plot(tide.time,tide.dz)
plt.xticks(rotation=70)
# Out:
# (array([ 736150.,  736157.,  736164.,  736171.]),
#  <a list of 4 Text xticklabel objects>)

# %%
#datetime.datenum(tide.time[0],'%f')
datetime.strftime(tide.time[2],'%S')#-tide.time[0])
# Out:
# '00'

# %%
#epoch = datetime.utcnow()
#(tide.time-epoch).total_seconds()
tide.time = [(tide.time[i]-tide.time[0]).total_seconds()  for i in range(len(tide.time))];

# %%
tide.to_csv('tide.txt',sep=' ',columns=['time','dz'],header=None,index=None)
